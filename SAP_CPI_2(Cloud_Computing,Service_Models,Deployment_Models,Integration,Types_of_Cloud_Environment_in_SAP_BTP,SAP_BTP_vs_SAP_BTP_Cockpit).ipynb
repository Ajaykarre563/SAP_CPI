# %% [markdown]
# # **what is mean by Cloud Computing?**

# %% [markdown]
# **🔹 Cloud Computing is the delivery of computing services—like storage, servers, databases, networking, software, and analytics—over the internet (“the cloud”) instead of on your local computer.**

# %% [markdown]
# # **👉 In short:**
#
# Instead of owning physical hardware/software, you use them as services via the internet.
#
# Examples: Google Drive, AWS, Microsoft Azure, Dropbox.
#
# # **✨ Benefits:**
#
# Pay only for what you use.
#
# Accessible from anywhere.
#
# Scalable (grow or shrink resources easily).
#
# Reduces hardware and maintenance costs.

# %% [markdown]
# # **Here are some simple real-life examples of cloud computing:**
#
# Google Drive, Dropbox, OneDrive → Store and share files online (Cloud Storage).
#
# Outlook, Gmail, Yahoo Mail → Email services hosted on the cloud (SaaS).
#
# Zoom, Microsoft Teams, Google Meet → Online communication tools.
#
# Netflix, YouTube, Spotify → Streaming platforms powered by cloud.
#
# AWS, Microsoft Azure, Google Cloud → Cloud providers offering infrastructure & services.
#
# 👉 So yes, Google Drive = Cloud Storage and Outlook = Cloud Email Service.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **1️⃣ Software as a Service (SaaS)**
#
# What it is: Ready-to-use applications delivered over the internet.
#
# User’s role: Just use the software, no need to install, maintain, or manage servers.
#
# Examples: Gmail, Google Drive, Outlook, Dropbox, Salesforce, Zoom.
#
# 👉 Think: Finished product you directly use.
#
# # **2️⃣ Platform as a Service (PaaS / iPaaS)**
#
# What it is: A platform for developers to build, run, and manage applications without worrying about infrastructure.
#
# User’s role: Develop and deploy apps, cloud handles OS, runtime, middleware.
#
# Examples:
#
# PaaS: Google App Engine, AWS Elastic Beanstalk, Heroku.
#
# iPaaS (Integration PaaS): SAP Integration Suite, Dell Boomi, MuleSoft (specialized for connecting apps/systems).
#
# 👉 Think: Playground for developers to build apps.

# %% [markdown]
# # **3️⃣ Infrastructure as a Service (IaaS)**
#
# What it is: Renting virtual computers, storage, and networking from the cloud instead of buying physical hardware.
#
# User’s role: You install and manage the operating system, apps, and data, while the cloud provider takes care of the physical hardware.
#
# Examples: AWS EC2, Microsoft Azure Virtual Machines, Google Compute Engine.
#
# 👉 Think: Like renting a computer from the cloud — you get the raw hardware, and you decide how to set it up.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **1️⃣ Public Cloud**
#
# What it is: Cloud resources are owned and managed by third-party providers and shared by many users.
#
# User’s role: Rent the services and pay as you go.
#
# Examples: AWS, Microsoft Azure, Google Cloud.
#
# 👉 Think: Like a public bus → anyone can buy a ticket and use it.
#
# # **2️⃣ Private Cloud**
#
# What it is: Cloud resources are used only by a single organization, either hosted on-site or by a provider.
#
# User’s role: More control, security, and customization.
#
# Examples: VMware Private Cloud, OpenStack, Microsoft Azure Stack.
#
# 👉 Think: Like a private car → only your organization uses it.
#
# # **3️⃣ Hybrid Cloud**
#
# What it is: A mix of public and private cloud, allowing data and applications to move between them.
#
# User’s role: Choose where to run apps (public for cost savings, private for security).
#
# Examples: AWS Outposts, Microsoft Azure Hybrid, Google Anthos.
#
# 👉 Think: Like using a private car + public transport depending on your need.
#
# ✅ In short:
#
# Public = Shared cloud (AWS, GCP)
#
# Private = Dedicated cloud (Only for one organization)
#
# Hybrid = Combination of both (flexibility)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Note:**
#
# On-Premise means the software/system is installed and runs on computers/servers inside the company’s own office or data center (not on the cloud).

# %% [markdown]
# **On-Premise to Cloud Integration → Connects your local company systems (like ERP/database in office) with cloud apps (like Salesforce, SAP SuccessFactors).**
#
# **Cloud to Cloud Integration → Connects two different cloud apps (like Salesforce ↔ ServiceNow, or Google Drive ↔ Slack).**
#
# 👉 Simple:
#
# Local system ↔ Cloud system
#
# Cloud system ↔ Cloud system

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Types of Cloud Environment in SAP BTP**

# %% [markdown]
# # **1️⃣ Neo Environment**
#
# What it is: SAP’s original cloud environment (older).
#
# Focus: Mainly used for building Java, HTML5, and SAP HANA-based applications.
#
# Limitation: Only hosted in SAP data centers (less flexibility).
#
# Example use: Deploying an SAPUI5 (Fiori) app connected to SAP HANA.
#
# 👉 Think: A specialized, SAP-only environment.
#
# # **2️⃣ Cloud Foundry Environment**
#
# What it is: A more modern, open, and flexible environment in SAP BTP.
#
# Focus: Supports multiple programming languages (Java, Node.js, Python, etc.) and services.
#
# Advantage: Runs not only on SAP data centers but also on hyperscalers like AWS, Azure, GCP, and Alibaba Cloud.
#
# Example use: Building an integration service with Node.js, or a machine learning app in Python.
#
# 👉 Think: A flexible, multi-cloud environment.

# %% [markdown]
# # **Difference between SAP BTP and SAP BTP Cockpit**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Steps to Enable Integration Suite in BTP Cockpit

# %% [markdown]
# ![image.png](data:image/png;base64,...)
